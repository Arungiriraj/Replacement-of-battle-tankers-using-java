# %%
import pandas

# %%
dataset=pandas.read_excel("project.xlsx")

# %%
dataset
# Out:
#     DISTANCE   PLAIN  FOREST       MUD  DESERT    RIVER  MOUNTAIN  \
# 0       1000  0.0400  0.0100  0.005000  0.0400  0.00800  0.020000
# 1       1500  0.0266  0.0066  0.003300  0.0266  0.00530  0.013300
# 2       2000  0.0200  0.0050  0.002500  0.0200  0.00400  0.010000
# 3       2500  0.0160  0.0040  0.002000  0.0160  0.00320  0.008000
# 4       3000  0.0133  0.0033  0.001600  0.0133  0.00266  0.006600
# 5       3500  0.0114  0.0028  0.001400  0.0114  0.00228  0.005700
# 6       4000  0.0100  0.0025  0.001200  0.0100  0.00200  0.005000
# 7       4500  0.0088  0.0022  0.001100  0.0088  0.00177  0.004440
# 8       5000  0.0080  0.0020  0.001000  0.0080  0.00160  0.004000
# 9       5500  0.0072  0.0018  0.000900  0.0072  0.00145  0.003630
# 10      6000  0.0066  0.0016  0.000830  0.0066  0.00130  0.003330
# 11      6500  0.0061  0.0015  0.000760  0.0061  0.00123  0.003070
# 12      7000  0.0057  0.0014  0.000710  0.0057  0.00114  0.002857
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(dataset.DISTANCE,dataset.PLAIN)
plt.plot(dataset.DISTANCE,dataset.FOREST)
plt.plot(dataset.DISTANCE,dataset.MUD)
plt.plot(dataset.DISTANCE,dataset.DESERT)
plt.show()
